# %% [markdown]
# # Diabetes Risk Factors in Pima Indian Population (COGS 108 - Final Project)

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [  ] YES - make available
# * [`X`] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; The goal of our project was to determine which health factors create a higher risk for diabetes within the female Pima Indian Population. Before we started our analysis we hypothesized that high levels of these variables: number of pregnancies, age, insulin and glucose would have the greatest risk for diabetes. We began this data science project by analyzing our [dataset](https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database). We removed any observations that not biologically possible and values that were missing. We also performed EDA to analyze the relationships between variables and the 'outcome' predictor variable, which indicated whether or not the patient had diabetes. Our results showed: pregnancies, glucose, insulin, BMI, and DiabetesPedigreeFunction seem to have a significant relationship with the likelihood of developing diabetes in the Pima Indian female population. Lastly, we created a KNN model and we found that setting k to be 11 was the most optimal. Our final model had a recall: 0.78, precesion: 0.96, and accuracy: 0.79.

# %% [markdown]
# # Names
#
# - Garrett Lam
# - Seshu Mallina
# - Andrea Behar
# - Vignesh Jayananth
# - Samantha Sheppard

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Is there a significant relationship between health factors, such as number of pregnancies, blood pressure, BMI, age, DiabetesPedigreeFunction, glucose, insulin, and skin thickness and the likelihood of developing diabetes in the Pima Indian female population?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; In the United States about 15 million women, or 1 in 9, have diabetes [^womenshealth]. Diabetes is categorized by the lack of insulin production or usage within the body which is important for regulating blood sugar levels that can result in serious health problems such as heart and kidney disease [^cdc]. The three main types of diabetes are type 1 which is an autoimmune disease, type 2 (most common) can occur at any point throughout your life, and gestational diabetes which can occur during pregnancy [^cdc]. Although diabetes is more prevalent in men, women experience more severe consequences, for example, women are at a more increased risk of dying from more heart disease than men and experience a larger risk of blindness [^ncbi].
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; One study analyzed different findings of the correlation between gestational diabetes and developing type 2 diabetes [^Jang].  Korean women were more likely to develop diabetes if they had experienced gestational diabetes previously. In Korea type 2 diabetes is reported in 10-15% of women postpartum. A following study revealed that 40% of women that had gestational diabetes were likely to develop type 2 diabetes within 5 years. In addition, one study found that within a population of mostly black women with gestational diabetes 10% developed type 2 diabetes after pregnancy. Finally, this study talked about, how in the year following delivery, 38% of women with gestational diabetes have a high incidence of diabetes, this study reported in a mixed ethnic population. This study also referenced obesity as a possible factor for developing diabetes.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Similarly, another study found that gestational diabetes ethnic origin can be a contributing factor in determining the prevalence of gestational diabetes and that some ethnic groups such as Black, South East Asian, and Indian had a higher frequency of gestational diabetes than white women [^Dornhorst]. Furthermore, another study found that particularly the Pima Indian population had a 19th fold incidence of diabetes compared to a similar population in the surrounding area and in the following years the risk of developing type 2 diabetes within this population has increased [^Schulz].
# The previous studies demonstrate the severe consequences women have when developing diabetes. The factors of weight and gestational diabetes have been prominently studied and there has also been research analyzing the relationship between ethnicity and risk for developing type 2 diabetes. In addition, within the US, the Pima Indians in particular have a high prevalence of type 2 diabetes when compared to other populations and this raised the question of how women within this population are affected and what factors contribute to the possibility of developing type 2 diabetes.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Another external piece we referenced was a research publication by Victor Chang and colleagues, they dug deep into the mechanics behind their proposal for an e-diagnosis system meant to detect a particular type of diabetes within a population. Their paper raised valid concerns regarding the accuracy of applied machine learning due to the fact that there is no way to account for the internal decision making process that takes place, also referred to as the black-box effect. This served as a reminder to take our limitations into account when interpreting and displaying data [^ncbiML].
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Another work we used as reference to gain better insight on this population was a journal by Eric Ravussin and colleagues with the American Diabetes Association. While the research conducted here was specified toward a slightly smaller age group and certain way of lifestyle that could influence the presence or absence of diabetes along with various cardiovascular diseases, the factors they focused on highly overlapped the ones we found interest in for our project: age, blood pressure, glucose, etc. This allowed us to gain a better understanding of what factors are most impactful on whether or not diabetes will appear at some point in life [^diabetesjournals].
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; The dataset we chose to focus on revolves around a particular group belonging to the Pima Indian tribe, located in parts of Arizona. The women of this tribe, ages 21 and older, have been studied for the purpose of predicting whether or not a person will have diabetes given the condition of certain health factors. Diabetes has been known to exist at significant rates within this subset of the Pima Indian community which allows for a solid foundation for data to be collected from. Granted, we found it interesting to interpret this data in order to see if our own model could concisely and accurately display the statistics representing this group.
#
# [^womenshealth]: https://www.womenshealth.gov/a-z-topics/diabetes#:~:text=Diabetes%20is%20a%20disease%20in,in%20every%209%20adult%20women.
# [^cdc]: https://www.cdc.gov/diabetes/basics/gestational.html
# [^ncbi]: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5861464/
# [^Jang]: https://doi.org/10.4093/dmj.2011.35.1.1
# [^Dornhorst]: https://pubmed.ncbi.nlm.nih.gov/1473322/
# [^Schulz]: https://doi.org/10.1007/s13679-014-0132-9
# [^ncbiML]:https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8943493/
# [^diabetesjournals]: https://diabetesjournals.org/care/article/17/9/1067/17885/Effects-of-a-Traditional-Lifestyle-on-Obesity-in

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Our group has two main hypotheses:
# - **Null hypothesis (H0):** There is no significant relationship between the number of pregnancies, cholesterol levels, blood pressure, BMI, age, and skin thickness and the likelihood of developing diabetes in the Pima Indian female population.
# - **Alternative hypothesis (H1):** There is at least one health factor (number of pregnancies, cholesterol levels, blood pressure, BMI, age, skin thickness) that has a significant relationship with the likelihood of developing diabetes in the Pima Indian female population.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; We believe BMI, blood pressure, cholesterol levels will have a significant relationship with one’s likelihood of developing diabetes in the Pima Indian female population, whereas number of pregnancies, skin thickness, and age will have an insignificant relationship with one's likelihood of developing diabetes in the Pima Indian female population.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; There is evidence that BMI, blood pressure, and cholesterol levels are all risk factors for the development of diabetes. BMI is a measure of body fat based on a person's height and weight. Studies have consistently shown that people with higher BMIs are at an increased risk of developing diabetes, as excess body fat can impair the body's ability to use insulin effectively. High blood pressure is also a known risk factor for diabetes, it can damage blood vessels and lead to insulin resistance, which is a key factor in the development of diabetes. Cholesterol levels have also been linked to an increased risk of diabetes. High levels of cholesterol can contribute to the buildup of plaque in the arteries, which can impair blood flow and increase the risk of developing insulin resistance. Therefore, it is reasonable to believe that there is a significant relationship between BMI, blood pressure, cholesterol levels, and the likelihood of developing diabetes [^diabetesjournals].
#
# [^diabetesjournals]: https://diabetesjournals.org/care/article/17/9/1067/17885/Effects-of-a-Traditional-Lifestyle-on-Obesity-in

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: Pima Indians Diabetes Database
# - Link to the dataset: https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database
# - Number of observations: 768 observations (rows) and 9 features (columns)
#
# This dataset originated from the National Institute of Diabetes and Digestive and Kidney Diseases. The dataset contains **eight** medical predictor variables and **one** target variable (Outcome), all patients are at least 21 years old females of Pima Indian heritage. "Outcome" is a binary variable with 1 indicating that the indivdual has diabetes and 0 if they do not. Predictor variables consist of number of pregnancies, BMI, age, insulin level, etc.
#
# We only chose to use this dataset for our final project because our group was interested in gestational diabetes. Based on our research above, the Pima Indian Female population is known to have a high likelihood of developing gestational diabetes. Additionally, this dataset that we found includes number of pregnancies and other health variables that were of interest, thus making it the best dataset that suited our needs.

# %% [markdown]
# # Setup

# %%
# import relevant Python packages
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import patsy
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier

warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Read in CSV file and printed first couple of rows

# %%
# Read in csv file using pandas
df = pd.read_csv("diabetes.csv")
# Print first couple of rows
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Understand the dimensions of data and the type of variable each variable is

# %%
# Get number of observations (rows) and features (columns)
print(df.shape)
# Check datatypes of columns
print(df.dtypes)
# Out:
# (768, 9)
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# Determine if there are any missing values in data

# %%
# Count the number of values that are empty
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# Althought there were no missing (NaN) values in our data, we noticed that some variables such as BMI, Skin Thickness, and Blood Pressure have values of 0. A value of 0 is not biologically possible for these variables, so we decided to drop these observations. Furthermore, according to a study on the Biology of Human Starvation, a BMI of under 9 appears to be fatal for human survival in females. So we will remove any observations with BMI < 9. [^james]
#
# [^james]: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1526048/

# %%
# Remove BMI that are under 9
df = df[df['BMI'] >= 9] 
# Remove BP that are 0
df= df[df['BloodPressure'] != 0]
# Remove ST that are 0
df = df[df['SkinThickness'] != 0]
# Print cleaned df
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 6            3       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 3                     0.167   21        0
# 4                     2.288   33        1
# 6                     0.248   26        1

# %% [markdown]
# Check to see if the observations with implausible values were removed

# %%
# Double check if dataframe got filtered properly, if one is true 
(df['BloodPressure'] == 0).any() or (df['SkinThickness'] == 0).any() or (df['BMI'] < 9).any()
# Out:
# False

# %% [markdown]
# For clarity, we decided to rename the "Outcome" column to "Diabetes". A value of 1 indicates that the individual has diabetes while 0 indicates that they do not.

# %%
# Rename column using rename method
df = df.rename(columns={'Outcome': 'Diabetes'})

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# ### Variable Definitions
#
# 1. **Pregnancies**: Number of times patient was pregnant
# 2. **Glucose**: Concentration of glucose after 2 hours [Used an oral glucose tolerance test]
# 3. **Blood Pressure**: Diastolic Blood Pressure (mmHg)
# 4. **Skin Thickness**: Skinfold thickness in triceps (mm)
# 5. **Insulin**: 2-hour serum insulin (mmU/mL)
# 6. **BMI**: Body Mass Index calculated using the formula (weight(kg)/ (height(m)^2))
# 7. **Diabetes Pedigree Function**: Function that scores the likelihood of diabetes based on family history
# 8. **Age**: How old they are in years
# 9. **Diabetes**: Boolean value 0 or 1 (1 indicates that the individual has diabetes while 0 indicates that they do not)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# Our first step in the EDA process is to get descriptive statistics for quantitative variable in dataframe.

# %%
# Use the describe method to return the quantative statistics for each variable
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   537.000000  537.000000     537.000000     537.000000  537.000000
# mean      3.510242  119.903166      71.469274      29.186220  113.960894
# std       3.304281   32.975142      12.302450      10.505807  122.894735
# min       0.000000    0.000000      24.000000       7.000000    0.000000
# 25%       1.000000   97.000000      64.000000      22.000000    0.000000
# 50%       2.000000  115.000000      72.000000      29.000000   90.000000
# 75%       5.000000  141.000000      80.000000      36.000000  165.000000
# max      17.000000  199.000000     110.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age    Diabetes
# count  537.000000                537.000000  537.000000  537.000000
# mean    32.890130                  0.501823   31.586592    0.333333
# std      6.875842                  0.343643   10.747286    0.471844
# ...

# %% [markdown]
# We can see the major statistics of each variable: *mean*, *st dev*, *quartiles*, *max*, and *min*.

# %% [markdown]
# Next, we need to count the number of occurances of people that have diabetes and that do not have diabetes. We decided to split our data into these populations:
#
# * **Population 0: People that do not have diabetes (negative).**
#
# * **Population 1: People that have diabetes (positive).**

# %%
# Use the countplot to display the number of people in each population
sns.countplot(data = df, x = "Diabetes")
# Out:
# <Axes: xlabel='Diabetes', ylabel='count'>

# %%
# Use value_counts method to count the number of occurences
negative = df['Diabetes'].value_counts()[0]
positive = df['Diabetes'].value_counts()[1]
# Print the number of occurences
print(f'Number of individuals in Population 0: {negative}')
print(f'Number of individuals in Population 1: {positive}')
# Out:
# Number of individuals in Population 0: 358
# Number of individuals in Population 1: 179

# %% [markdown]
# We can observe that in the dataset there is are more people in population 0 (358) than there are in population 1 (179). This indicates that our data is slightly skewed towards individuals without diabetes. In an ideal dataset, we would want these to be equal.

# %% [markdown]
# Our next step was to understand the distributions of the different variables. We decided to use a histogram to visualize the distribtions. We included the KDE parameter in our histograms because we wanted to see the probaility density curve for each variable.

# %%
# Color array, a different color for each variable
c = ['blue', 'red','orange','purple', 'green','magenta','yellow','cyan','pink']

j = 1
plt.figure(figsize=(25,10)) 
# For each variable make a histogram
for i, variable in enumerate(df.columns):
    plt.subplot(2, 5, j)
    # Plot the histogram to show skewness of each variable and use kde paramter to show probability distribution
    sns.histplot(data = df, x = variable, kde = True, color = c[i])
    j = j + 1

# %% [markdown]
# In order to check for any outliers in our data, we decided to create boxplots for each variable. Any data points outside of the minimum (Q0) and maximum (Q4) are considered outliers.

# %%
# We know that there are 9 variables we are observing
# Use same color scheme as above 
i = 1
plt.figure(figsize=(25,8)) 
for variable in range(0,9):
    plt.subplot(2, 5, i)
    # Plot the boxplots to show outliers of each variable
    sns.boxplot(df[df.columns[variable]], color = c[variable])
    i = i + 1

# %% [markdown]
# Unfortunately, we notice that there are outliers in every single variable. Some variables have more outliers than others. For example, DiabetesPedigreeFunction and Insulin levels have more outliers than SkinThickness and Glucose levels.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# Our next step is to conduct bivariate analysis to identify if there are any relationships between variables. A good first step for this is to first compute the correlation of determination (R^2) between each variable using a clustermap/heatmap.

# %%
# Use heatmap to find correlation of determination (R^2) between all the variables
sns.clustermap(df.corr(), annot= True)

# %% [markdown]
# In this data science project, we are only interested in variables that have a high correlation with the diabetes indicator. From the heatmap we can observe: glucose (0.46), age (0.32), BMI (0.31), Pregnancies &SkinThickness (0.26), DBF (0.23), Insulin (0.21), BP (0.19). The top 3 variables that correlate to the diabetes target variable are glucose, age, and BMI.

# %% [markdown]
# We wanted to know the distributions of each predictor variable within the two populations. Therefore, as a group, we decided to create a boxplot for each variable in population 0 and 1. The boxplot allows us to determine variability and skewness of the data wiithin each population individually.

# %%
i = 1
plt.figure(figsize=(20,15)) 
# For each variable compare the two populations, we do not iterate to the last column because that would be Diabetes on both axes
for column in df.columns[:-1]:
    plt.subplot(2, 4, i)
    # Plot boxplots for each variable to compare the populations 
    sns.boxplot(x = 'Diabetes', y = column , data = df)
    i = i + 1

# %% [markdown]
# From the boxplots above, we can see that:
# - The variables that are symmetric in population 0 are: BMI
# - The variables that are right skewed in population 0 are: Pregnancies, Glucose, Age, DiabetesPedigreeFunction,
# - The variables that are left skewed in population 0 are: Insulin, SkinThickness, BloodPressue
# - The variables that are symmetric in population 1 are: Glucose, Age, and DiabetesPedigreeFunction
# - The variables that are right skewed in population 1 are: Pregnancies, BMI, SkinThickness, and BloodPressue
# - The variables that are left skewed in population 1 are: Insulin
# - Pregnancies has the highest variability in population 1 due to it having the largest spread/range
# - BloodPressure has the highest variability in population 0 due to it having the largest spread/range

# %% [markdown]
# To dig deeper for our bivariate analysis, we decided to use kernel density estimation (KDE) plots because it allows us to calculate the probability density function of a random variable in accordance with the correlation of the target variable diabetes. By using this graph, we can see the distributation of each variable in relation to the two different populations we are studying.

# %%
# We do not need to study outcome with outcome
i = 1
plt.figure(figsize=(25,10)) 
# For each variable make a KDE plot
for column in df.columns[:-1]:
    plt.subplot(2, 4, i)
    # Population 0 blue
    sns.kdeplot(df.loc[df['Diabetes'] == 0, column], shade = True, label = 'No Diabetes')
    # Population 1 orange
    sns.kdeplot(df.loc[df['Diabetes'] == 1, column], shade = True, label = 'Diabetes')
    plt.legend()
    i = i + 1

# %% [markdown]
# Earlier in our analysis, the heatmap suggested that glucose, BMI, and age are the top three variables that correlate to diabetes. This is further evidenced by the KDE graphs above as we can see in the glucose, BMI, and age graphs, there is a larger difference in their probability density function curves and less overlap between the two populations. On the other hand, we can see that that variables that have large overlaps between the two populations are less indicative of correlating to having diabetes i.e. Blood Pressure had the least correlation and also had the most overlap between the two populations.

# %% [markdown]
# The bivariate analysis conducted above suggested that the top 3 variables that correlate to the diabetes target variable are glucose, age, and BMI. However, we cannot just conclude this solely based on R^2 values alone. To further investigate the predictor variables in our data, we decided use Ordinary Least Squares (OLS) linear regression to test for statistical significant correlation via their p values. OLS linear regression also allows us to identify the variables that have a strong linear relationship with risk of diabetes. If we do find a particular variable to have a strong linear relationship, we could use this variable to estimate one's likelihood of developing diabetes within this population.

# %%
# Conatiner to store p values for each variable
p_values = []

# %%
# For each variable we want to calculate the p value and linear regression using OLS technique
# This line uses the patsy library to create a design matrix of the dependent variable (outcome) 
# and independent variable (predictors). The formula 'Diabetes ~ Pregnancies' specifies that 
# we want to model the relationship between the Diabetes column in the df dataframe and the 
# Pregnancies column.
outcome, predictors = patsy.dmatrices('Diabetes ~ Pregnancies', data=df) 

# This line creates an instance of an ordinary least squares (OLS) regression model using the 
# statsmodels library. The outcome and predictors variables from the previous line are passed 
# as arguments to the sm.OLS() function.
mod = sm.OLS(outcome, predictors)

# This line fits the OLS model to the data using the fit() method of the mod object. 
# The resulting model is stored in the res variable.
res = mod.fit()

# Add to list of p values
p_values.append(res.pvalues[0])

#  This line generates a summary of the regression results, including the estimated coefficients, 
# standard errors, t-values, p-values, and various goodness-of-fit statistics. The output is printed to the console.
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Diabetes   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     37.80
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):           1.54e-09
# Time:                        19:04:17   Log-Likelihood:                -339.80
# No. Observations:                 537   AIC:                             683.6
# Df Residuals:                     535   BIC:                             692.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.2046      0.029      7.115      0.000       0.148       0.261
# ...

# %%
# see comments above 
outcome1, predictors1 = patsy.dmatrices('Diabetes ~ Glucose', data=df) 
mod1 = sm.OLS(outcome1, predictors1)
res1 = mod1.fit()
p_values.append(res1.pvalues[0])
res1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Diabetes   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.214
# Method:                 Least Squares   F-statistic:                     146.8
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):           5.09e-30
# Time:                        19:04:17   Log-Likelihood:                -293.04
# No. Observations:                 537   AIC:                             590.1
# Df Residuals:                     535   BIC:                             598.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4627      0.068     -6.790      0.000      -0.597      -0.329
# ...

# %%
# see comments above 
outcome2, predictors2 = patsy.dmatrices('Diabetes ~ BloodPressure', data=df) 
mod2 = sm.OLS(outcome2, predictors2)
res2 = mod2.fit()
p_values.append(res2.pvalues[0])
res2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Diabetes   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     19.05
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):           1.53e-05
# Time:                        19:04:17   Log-Likelihood:                -348.73
# No. Observations:                 537   AIC:                             701.5
# Df Residuals:                     535   BIC:                             710.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# see comments above 
outcome3, predictors3 = patsy.dmatrices('Diabetes ~ SkinThickness', data=df) 
mod3 = sm.OLS(outcome3, predictors3)
res3 = mod3.fit()
p_values.append(res3.pvalues[0])
res3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Diabetes   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     38.17
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):           1.29e-09
# Time:                        19:04:17   Log-Likelihood:                -339.62
# No. Observations:                 537   AIC:                             683.2
# Df Residuals:                     535   BIC:                             691.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
# see comments above 
outcome4, predictors4 = patsy.dmatrices('Diabetes ~ Insulin', data=df) 
mod4 = sm.OLS(outcome4, predictors4)
res4 = mod4.fit()
p_values.append(res4.pvalues[0])
res4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Diabetes   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     24.40
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):           1.05e-06
# Time:                        19:04:17   Log-Likelihood:                -346.15
# No. Observations:                 537   AIC:                             696.3
# Df Residuals:                     535   BIC:                             704.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2420      0.027      8.898      0.000       0.189       0.295
# ...

# %%
# see comments above 
outcome5, predictors5 = patsy.dmatrices('Diabetes ~ BMI', data=df) 
mod5 = sm.OLS(outcome5, predictors5)
res5 = mod5.fit()
p_values.append(res5.pvalues[0])
res5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Diabetes   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.092
# Method:                 Least Squares   F-statistic:                     55.42
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):           3.92e-13
# Time:                        19:04:17   Log-Likelihood:                -331.66
# No. Observations:                 537   AIC:                             667.3
# Df Residuals:                     535   BIC:                             675.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3582      0.095     -3.774      0.000      -0.545      -0.172
# ...

# %%
# see comments above 
outcome6, predictors6 = patsy.dmatrices('Diabetes ~ DiabetesPedigreeFunction', data=df) 
mod6 = sm.OLS(outcome6, predictors6)
res6 = mod6.fit()
p_values.append(res6.pvalues[0])
res6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Diabetes   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     31.14
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):           3.82e-08
# Time:                        19:04:17   Log-Likelihood:                -342.94
# No. Observations:                 537   AIC:                             689.9
# Df Residuals:                     535   BIC:                             698.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
# see comments above 
outcome7, predictors7 = patsy.dmatrices('Diabetes ~ Age', data=df) 
mod7 = sm.OLS(outcome7, predictors7)
res7 = mod7.fit()
p_values.append(res7.pvalues[0])
res7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Diabetes   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.101
# Method:                 Least Squares   F-statistic:                     60.91
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):           3.16e-14
# Time:                        19:04:17   Log-Likelihood:                -329.17
# No. Observations:                 537   AIC:                             662.3
# Df Residuals:                     535   BIC:                             670.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1100      0.060     -1.834      0.067      -0.228       0.008
# ...

# %% [markdown]
# We will be using a p-value cutoff of 0.05 to determine whether a variable is significantly correlated to one's likelihood of developing diabetes or not. From the OLS linear regression tests above we can see that:
# - Age: 0.067 > 0.05
# - DiabetesPedigreeFunction: 0 < 0.05
# - BMI: 0 < 0.05
# - Insulin: 0 < 0.05
# - SkinThickness: 0.932 > 0.05
# - BloodPressure: 0.139 > 0.05
# - Glucose: 0 < 0.05
# - Pregnancies: 0 < 0.05
#
# Please note that the p values that are 0 are not exactly 0. They are very close to 0 so the program rounded it off to be 0. The variables that are statistically significant are: DiabetesPedigreeFunction, BMI, Insulin, Glucose, and Pregnancies. The variables that are not statistically significant are: Age, SkinThickness, and BloodPressure.

# %% [markdown]
# For better visiualization, we will print the exact p values for each variable below:

# %%
i = 0
# Print out the column and its p-value
for column in df.columns[:-1]:
    print("The p-value for", column, "is:", p_values[i])
    i = i + 1
# Out:
# The p-value for Pregnancies is: 3.6033237524884886e-12
# The p-value for Glucose is: 2.9911818072305505e-11
# The p-value for BloodPressure is: 0.13919548661634978
# The p-value for SkinThickness is: 0.9323771078829568
# The p-value for Insulin is: 8.812495272124502e-18
# The p-value for BMI is: 0.00017836076967404194
# The p-value for DiabetesPedigreeFunction is: 1.306362915783349e-06
# The p-value for Age is: 0.0672365517628025

# %% [markdown]
# This concludes our bivariate analysis. We then wanted to explore the data more by using multivariate analysis.

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# For our multivariate analysis, we decided to use pairplots as it allows us to visualize the heatmap correlations and more easily compare the distributions of the KDE graphs & the scatter plots of all the different variables.

# %%
# Use the hue to show the different populations we are currently studying
sns.pairplot(df, hue = "Diabetes")

# %% [markdown]
# ### K-Nearest Neighbors (KNN)

# %% [markdown]
# Finally, we decided to build a K-nearest neighbor (KNN) machine learning model. The KNN algorithm is a non-parametric, supervised learning algorithm often used for classification of data. Our group decided to use KNN as it is a simple machine learning algorithm that classifies a point by comparing it to it’s k nearest neighbors. By using this algorithm, we can better predict the chances of a patient having diabetes by comparing the new patient’s data to the existing database. From the EDA conducted above, we determined that the variables: Age, SkinThickness, and BloodPressure are not statistically significant. Therefore, we decided to drop these variable from our dataset before we run KNN.
#
# The first step of KNN is to normalize the data. This is done using the Standard Scalar method which normalizes data based on its z-score.

# %%
# This line creates an instance of the StandardScaler class, which will be used to scale the data.
scalar = StandardScaler()

# This line applies the fit_transform method of the StandardScaler object to the data in the df dataframe, excluding the columns 
# "Age", "SkinThickness", "BloodPressure", and "Diabetes". The resulting scaled and transformed data is stored in a new dataframe 
# called transformed, with columns named "Pregnancies", "Glucose", "Insulin", "BMI", and "DiabetesPedigreeFunction".
transformed =  pd.DataFrame(scalar.fit_transform(df.drop(["Age","SkinThickness","BloodPressure","Diabetes"],axis = 1),), 
        columns=['Pregnancies', 'Glucose', 'Insulin','BMI', 'DiabetesPedigreeFunction'])

# This line creates a new variable called dependent that contains the Diabetes column from the original df dataframe. 
# This column will be used as the dependent variable in a machine learning model.
dependent = df.Diabetes

# %%
# Print the first couple observations of the transformed dataframe
transformed.head()
# Out:
#    Pregnancies   Glucose   Insulin       BMI  DiabetesPedigreeFunction
# 0     0.754197  0.852856 -0.928170  0.103337                  0.364604
# 1    -0.760402 -1.059456 -0.928170 -0.915669                 -0.439304
# 2    -0.760402 -0.938039 -0.162574 -0.697311                 -0.975242
# 3    -1.063322  0.518960  0.440129  1.486275                  5.202612
# 4    -0.154562 -1.271935 -0.211442 -0.275151                 -0.739313

# %% [markdown]
# We are going to split the data randomly into training and testing data using 70/30 split. The train_test_split() function ensures that training and testing data are randomly selected.

# %%
# This line applies the train_test_split function to the scaled and transformed data (transformed) and the dependent 
# variable (dependent). The resulting split data is stored in four separate variables: transformed_train, transformed_test, 
# dependent_train, and dependent_test.
# transformed_train: This variable contains the training dataset for the scaled and transformed data.
# transformed_test: This variable contains the testing dataset for the scaled and transformed data.
# dependent_train: This variable contains the training dataset for the dependent variable.
# dependent_test: This variable contains the testing dataset for the dependent variable.
# The test_size parameter is set to 0.30, which means that 30% of the data will be used for testing and 
# 70% will be used for training. The random_state parameter is set to 42, which ensures that the same random splits 
# are generated every time the code is run. The stratify parameter is set to dependent, which ensures that the training and 
# testing datasets have the same proportion of values for the Diabetes column as the original dataset. 
# This is particularly useful when the dependent variable is imbalanced.
transformed_train,transformed_test,dependent_train,dependent_test = train_test_split(transformed,dependent,test_size=0.30,random_state=42, stratify=dependent)

# %%
# Containers to hold testing and training data
test = []
train = []

for i in range(1,12):
    # This line creates an instance of the KNeighborsClassifier class with i neighbors.
    knn = KNeighborsClassifier(i)
    # This line fits the KNN model to the training dataset, using the fit method of the KNeighborsClassifier object.
    knn.fit(transformed_train,dependent_train)
    
    # These lines use the score method of the KNeighborsClassifier object to calculate the accuracy score of the model 
    # on the training and testing datasets, respectively. The resulting scores are then appended to the train and test lists.
    # At the end of this loop, the train and test lists will contain the accuracy scores for the KNN model on the training and testing datasets, 
    # respectively, for values of i ranging from 1 to 11. These scores can be used to evaluate the performance of the model 
    # and select the optimal value of i.
    train.append(knn.score(transformed_train,dependent_train))
    test.append(knn.score(transformed_test,dependent_test))

# %% [markdown]
# We will use a lineplot to determine the best k value to use for our model

# %%
# This line creates a new figure object with a width of 10 inches and a height of 5 inches, using the figure method of the 
# pyplot module from the matplotlib library.
#plt.figure(figsize=(10,5))

# This line creates a line plot using the lineplot method of the Seaborn (sns) library. The range(1,12) function is used to 
# specify the x-axis values (i.e., the number of neighbors used in the KNN model), and the train list is used to specify the 
# y-axis values (i.e., the accuracy scores on the training dataset). The label parameter is used to set the label for the line 
# to "Train", which will be used in the plot legend.
fig, ax = plt.subplots()
sns.lineplot(x=range(1, 12), y=train, label='Train', ax=ax)
sns.lineplot(x=range(1, 12), y=test, label='Test', ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# From the graph we can see that the max testing score occurs when k = 11. We will use this k to to make the model.

# %%
# Setup a knn classifier with k neighbors
knn = KNeighborsClassifier(11)

# This line fits the KNN model to the training dataset using the fit method of the KNeighborsClassifier object. 
# The transformed_train and dependent_train variables contain the feature and target variables, respectively, 
# for the training dataset.
knn.fit(transformed_train,dependent_train)

# This line evaluates the performance of the KNN model on the testing dataset using the score method of the 
# KNeighborsClassifier object. The transformed_test and dependent_test variables contain the feature and target variables, 
# respectively, for the testing dataset. The resulting score variable contains the accuracy score of the KNN model on the 
# testing dataset. By calling the fit method on the KNeighborsClassifier object with the training dataset, we are training 
# the model to learn the relationships between the feature variables and the target variable. Once the model is trained, 
# we can evaluate its performance on the testing dataset by calling the score method with the testing dataset. 
# The resulting accuracy score provides a measure of how well the model generalizes to new, unseen data.
score = knn.score(transformed_test,dependent_test)

print(f"The best test score produced by our model is {score}, where k = 11")
# Out:
# The best test score produced by our model is 0.7901234567901234, where k = 11

# %% [markdown]
# To evaluate our KNN Model, we will be using a confusion matrix to calculate recall, precision, and accurarcy of our model.

# %%
# Let us get the predictions using the classifier we had fit above
# This line uses the predict method of the KNeighborsClassifier object to make predictions on the testing dataset. 
# The transformed_test variable contains the feature variables for the testing dataset. The resulting prediction 
# variable contains the predicted target variable values.
prediction = knn.predict(transformed_test)

# This line uses the confusion_matrix function from the sklearn.metrics module to generate a confusion matrix for 
# the predictions. The dependent_test variable contains the true target variable values for the testing dataset, 
# and the prediction variable contains the predicted target variable values. The resulting confusion matrix is a 
# table that summarizes the number of true positives, true negatives, false positives, and false negatives for the 
# model's predictions.
confusion_matrix(dependent_test,prediction)

# This line creates a cross-tabulation table using the crosstab function from the pandas library. The dependent_test 
# variable contains the true target variable values for the testing dataset, and the prediction variable contains the 
# predicted target variable values. The resulting table shows the number of actual and predicted values for each class 
# in the target variable, as well as the total counts (margins) for each row and column. The rownames and colnames 
# parameters are used to specify the names of the rows and columns in the table, respectively.
pd.crosstab(dependent_test, prediction, rownames=['Predicted'], colnames=['Actual'], margins=True)
# Out:
# Actual       0   1  All
# Predicted
# 0          104   4  108
# 1           30  24   54
# All        134  28  162

# %%
# Recall is a measure of how many of the actual positive results were correctly identified by the model. 
# It is calculated as the number of true positives (TP) divided by the sum of true positives and false negatives (FN). 
# A high recall score indicates that the model produces few false negatives.
recall = 104/(104+30)

# Precision is a measure of how many of the predicted positive results were actually positive. 
# It is calculated as the number of true positives (TP) divided by the sum of true positives and false positives (FP). 
# A high precision score indicates that the model produces few false positives.
precision = 104/(104+4)

# Accuracy is a measure of how often the model makes correct predictions. It is calculated as the number of true positives 
# (TP) plus true negatives (TN) divided by the total number of predictions. A high accuracy score indicates that the model 
# produces few false positives and false negatives.
accuracy = (104 + 24)/(104+4+24+30)

print(f"Recall: {recall}")
print(f"Precision: {precision}")
print(f"Accuracy: {accuracy}")
# Out:
# Recall: 0.7761194029850746
# Precision: 0.9629629629629629
# Accuracy: 0.7901234567901234

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; An ethical concern that we had was informed consent. As we did not collect the data from the datasets ourselves, it was difficult to check if the human subjects had given informed consent. However, as we are using the data, we can ensure that it is being used ethically. Our goal is to look into the correlation between health factors and diabetes in females of Pima Indian Heritage. The outcomes of our project can be used to aid in the prevention of diabetes for the group in our study. In terms of privacy, it seems as though personally identifiable information was not collected in the data. The data collected was anonymous and only data relevant to possible factors of diabetes was collected.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; One possible bias is that some of the data we looked at were from a specific gender. All the data collected was from women that were at least 21 years old. Furthermore, the data was also specifically collected from people of Pima Indian Heritage. It is important to note that although we planned on looking at a specific group of people known to have a high prevalence of diabetes, and to look into a factor like pregnancy, it is something to consider when analyzing the data. For example this leads to an equitable impact issue as this data does not impact everyone equally. This data should be looked at specifically with females of Pima Indian Heritage in mind.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Another bias we took into consideration was that some values that were 0 did not make sense in some of the data we were looking at. For example, the skin thickness from some of the data was collected as 0. We took this to mean that the thickness was just not measured as that made sense over skinless human subjects. Thus, we planned to clean up our data with this in mind during the analysis process. We also noted that it was not told when the insulin and glucose was measured. As glucose and insulin levels fluctuate throughout the day, this is important to keep in mind post-analysis. This could lead to a bias in the data as subjects may have had their levels measured at different times of the day.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; In our project, our goal was to determine which health factors created a higher risk of diabetes within the female Pima Indian Population. More specifically, we looked at if the number of pregnancies, blood pressure, BMI, age, DiabetesPedigreeFunction, glucose, insulin, and skin thickness had a significant relationship with the likelihood of developing diabetes in the Pima Indian female population. We hypothesized that between the number of pregnancies, cholesterol levels,blood pressure, BMI, age, and skin thickness, at least one of these factors would have a significant relationship with the likelihood of developing diabetes in the Pima Indian female population. Our null hypothesis was there is no significant relationship between the number of pregnancies, cholesterol levels, blood pressure, BMI, age, and skin thickness and the likelihood of developing diabetes in the Pima Indian female population.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; After cleaning and analyzing our data, we found that glucose, age, and BMI had the highest correlation with diabetes. Respectively, their correlations of determination were 0.46,0.32,and 0.31. After further data analysis, we then used Ordinary Least Squares linear regression to test for statistical significant correlation via their p-values. We found that the variables with p-values less than 0.05 were DiabetesPedigreeFunction, BMI, Insulin, Glucose, and Pregnancies. After seeing that these seemed to be the biggest predictors of diabetes in the Pima Indian female population, we decided to build a K-nearest neighbor machine learning model to predict a patient's chances of having diabetes. In conclusion the five variables that we used in our model and that had p-values less than 0.05 (pregnancies, glucose, insulin, BMI, and DiabetesPedigreeFunction) seem to have a significant relationship with the likelihood of developing diabetes in the Pima Indian female population. Note that this means we can reject our null hypothesis. However, there are some limitations to our project.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; An important factor to note is that when we look at the distribution of the variables in reference to the two populations we can see that many variables have outliers. Pregnancies, age, and insulin having the most outliers. We can also see that our data is skewed more to towards population 0 since there are 358 individuals in population 0 and 179 in population 1. This suggests that our KNN model might not be able to as accurately predict an individual’s chances of developing diabetes since the data points most often reflect categorization to population 0. For future analysis, we would implement a choice-based sampling approach which balances the data by taking a random sample size N of each population and variable so the number of individuals within each population is balanced for each variable.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  The main limitation of our project is that the data set is limited to the very specific population that cannot be generalized. Since we are looking specifically at Pima Indian women, this data set is not representative of a general population so we cannot generalize our findings or use our predictive algorithm to estimate a patient’s chances of developing diabetes. To add on, we do not know the specific type of diabetes (type 1, type 2, and gestational diabetes) for each individual in the study, so we can not generalize our findings to a specific type of diabetes. Furthermore, there were only a couple variables that were statistically significant risk factors of diabetes: pregnancies, glucose, insulin, BMI, and DiabetesPedigreeFunction. These factors were statistically significant for our population, but again could not be generalized for a larger population as there could be other variables that were not measured that could be potential risk factors. Finally, we were able to predict, using the statistically significant variables, the chances of a patient in this data set developing diabetes with a 79% accuracy, which is good but still results in a 21% chance of error. In the future, we would hope to improve our predictive algorithm to decrease the error margin and incorporate more diverse datasets into our analysis of variables that could be risk factors in developing diabetes.

# %% [markdown]
# # Team Contributions

# %% [markdown]
# Seshu Mallina: Found dataset, Edited research question, Performed data cleaning/EDA, Worked on KNN Model
#
# Garrett Lam: Formulated hypothesis, Created research question, Performed data cleaning/EDA, Worked on KNN Model
#
# Samantha Sheppard: Project timeline, Assisted with EDA, background and prior work, wrote overview
#
# Vignesh Jayananth: Ethics and Privacy, Assisted with data cleaning, data analysis, conclusion
#
# Andrea Behar: Background and prior work, Assisted with EDA, data analysis, conclusion
